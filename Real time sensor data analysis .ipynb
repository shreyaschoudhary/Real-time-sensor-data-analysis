# %% [markdown]
# ##Real time sensor data analysis

# %% [markdown]
# The data provided for the assigment was in .txt file, and hence was converted to csv file, which is more compatible with python platform.
#
# csv file can be found here : https://drive.google.com/file/d/1sn3-W6JPHd_C2gH8udIFNrzY06QYq6V0/view?usp=sharing

# %%
#Importing the necessary libraries
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt
import statistics as st
import seaborn as sns

# %%
#Reading the data into a dataframe
data = pd.read_csv('https://raw.githubusercontent.com/shreyaschoudhary/Process-Data-Analytics/master/Data4T_expt_clean.csv')

# %%
#Displaying the given data in the dataframe
data
# Out:
#       Time (Sec.)  Cold (Volts)  ...  T4 (Deg C)  T5 (Deg C)
# 0              46          2.77  ...       40.89       33.09
# 1              48          2.78  ...       41.43       32.73
# 2              50          2.78  ...       39.80       33.64
# 3              52          2.83  ...       39.80       33.09
# 4              54          2.80  ...       41.07       33.27
# ...           ...           ...  ...         ...         ...
# 2985         6016          2.46  ...       41.43       34.91
# 2986         6018          2.46  ...       41.98       33.82
# 2987         6020          2.45  ...       42.70       35.45
# 2988         6022          2.46  ...       41.61       34.00
# 2989         6024          2.49  ...       42.88       34.54
#
# [2990 rows x 8 columns]

# %% [markdown]
# -----------------------Part (A)---------------------------------------

# %%
#Initializing variables to the volts data for cold, hot and total sensors
coldv = data['Cold (Volts)']
hotv = data['Hot (Volts)']
totalv = data['Total (Volts)']

# %%
#Converting to Mass flow rates based on the emperical equation provided in the document
data['mcw'] = (1.256 + (178.032*(np.sqrt(coldv))))
data['mhw'] = (1.444 + (181.574*(np.sqrt(hotv))))
data['mt'] = (-2.319 + (355.822*(np.sqrt(totalv))))

# %%
#Adding the mass flow rates to the dataframe and printing it
data
# Out:
#       Time (Sec.)  Cold (Volts)  ...         mhw          mt
# 0              46          2.77  ...  314.889322  593.085088
# 1              48          2.78  ...  314.362965  598.377673
# 2              50          2.78  ...  316.985970  595.207747
# 3              52          2.83  ...  311.186041  592.020915
# 4              54          2.80  ...  316.463116  610.893531
# ...           ...           ...  ...         ...         ...
# 2985         6016          2.46  ...  314.362965  605.709900
# 2986         6018          2.46  ...  312.248624  439.244490
# 2987         6020          2.45  ...  311.186041  592.020915
# 2988         6022          2.46  ...  311.717787  606.750156
# 2989         6024          2.49  ...  310.653380  605.709900
#
# [2990 rows x 11 columns]

# %% [markdown]
# ------------------------Part (B)-------------------------------

# %%
#Plotting the mass flow rates of cold water, hot water and total with respect to time
t = data['Time (Sec.)']
cw= data['mcw']
hw = data['mhw']
tot = data['mt']
plt.figure(figsize=(20,10)) 
plt.plot(t, cw, label = 'Cold Water')                                     #Plotting Mass flow rate of cold water v/s time
plt.plot(t,hw,label = 'Hot Water')                                        #Plotting Mass flow rate of hot water v/s time
plt.plot(t,tot,label = 'Total')                                           #Plotting total Mass flow rate v/s time
plt.xlabel('Time (Sec.)', fontsize=12)
plt.ylabel('Mass flow rates of cw, hw and total (kg/h)',fontsize=12)
plt.title('Mass flow rates V/s Time plot',fontsize=18)
plt.legend()

# %%
#Splitting the flow rates data based on the plot above
cw1 = cw.iloc[0:1500]           #Split 1 for cold water flow rate
cw2 = cw.iloc[1990:]            #Split 2 for cold water flow rate
hw1= hw.iloc[0:1500]            #Split 1 for hot water flow rate
hw2= hw.iloc[1990:]             #Split 2 for hot water flow rate
tot1= tot.iloc[0:1500]          #Split 1 for total flow rate
tot2 = tot.iloc[1990:]          #Split 2 for total flow rate

# %%
#Calculating mean of the split data for each flow rates

#For cold water mass flow rate
meancw1 = st.mean(cw1)
meancw2 = st.mean(cw2)

#For hot water mass flow rate
meanhw1 = st.mean(hw1)
meanhw2 = st.mean(hw2)

#For total mass flow rate
meantot1 = st.mean(tot1)
meantot2 = st.mean(tot2)

#Printing the values
print("The mean of first split of data for flow rate of cold water (kg/h), containing 1500 points is:", meancw1)
print("The mean of second split of data for flow rate of cold water (kg/h), containing 1000 points is:", meancw2)

print("The mean of first split of data for flow rate of hot water (kg/h), containing 1500 points is:", meanhw1)
print("The mean of second split of data for flow rate of hot water (kg/h), containing 1000 points is:", meanhw2)

print("The mean of first split of data for total flow rate (kg/h), containing 1500 points is:", meantot1)
print("The mean of second split of data for total flow rate (kg/h), containing 1000 points is:", meantot2)
# Out:
# The mean of first split of data for flow rate of cold water (kg/h), containing 1500 points is: 298.2059005723744
# The mean of second split of data for flow rate of cold water (kg/h), containing 1000 points is: 283.3653771869299
# The mean of first split of data for flow rate of hot water (kg/h), containing 1500 points is: 314.44482790108344
# The mean of second split of data for flow rate of hot water (kg/h), containing 1000 points is: 316.5287028348515
# The mean of first split of data for total flow rate (kg/h), containing 1500 points is: 596.0060101949366
# The mean of second split of data for total flow rate (kg/h), containing 1000 points is: 600.6929905670453

# %%
#Calculating variance of the split data for each flow rates

#For cold water mass flow rate
varcw1 = st.variance(cw1)
varcw2 = st.variance(cw2)

#For hot water mass flow rate
varhw1 = st.variance(hw1)
varhw2 = st.variance(hw2)

#For total mass flow rate
vartot1 = st.variance(tot1)
vartot2 = st.variance(tot2)

#Printing the values
print("The variance of first split of data for flow rate of cold water (kg/h), containing 1500 points is:", varcw1)
print("The variance of second split of data for flow rate of cold water (kg/h), containing 1000 points is:", varcw2)

print("The variance of first split of data for flow rate of hot water (kg/h), containing 1500 points is:", varhw1)
print("The variance of second split of data for flow rate of hot water (kg/h), containing 1000 points is:", varhw2)

print("The variance of first split of data for total flow rate (kg/h), containing 1500 points is:", vartot1)
print("The variance of second split of data for total flow rate (kg/h), containing 1000 points is:", vartot2)
# Out:
# The variance of first split of data for flow rate of cold water (kg/h), containing 1500 points is: 5.16158082476437
# The variance of second split of data for flow rate of cold water (kg/h), containing 1000 points is: 4.288059898577254
# The variance of first split of data for flow rate of hot water (kg/h), containing 1500 points is: 11.849448025788195
# The variance of second split of data for flow rate of hot water (kg/h), containing 1000 points is: 14.0758354284429
# The variance of first split of data for total flow rate (kg/h), containing 1500 points is: 201.89550169064103
# The variance of second split of data for total flow rate (kg/h), containing 1000 points is: 141.64658752820503

# %% [markdown]
# Part (C)

# %% [markdown]
# Removing outliers now

# %%
#Function for checking the values for limits between mean plus mins 3 sigma and replacing the ones not in the range with average value of the column
# source: https://stackoverflow.com/questions/33115996/how-do-i-search-a-list-for-a-number-between-two-values
def between(l1,low,high):
    l2 = []
    for i in l1:
        if (i > low and i < high):                      #Checking for the values within the range of mean plus minus 3 sigma
            l2.append(i)                                #Appending the values satisfied to the list l2
        else:
            l2.append(st.mean(l1))                      #Replacing the values which are outside the limits with the average mean of the column and appending to the list l2    
               
    return l2

# %%
#Filtering out values in the range of mean plus minus 3 sigma from the two splits for cold water mass flow rates

#Split 1
lcw1 = meancw1 + (3*(np.sqrt(varcw1)))
lcw2 = meancw1 - (3*(np.sqrt(varcw1)))

#Split 2
lcw3 = meancw2 + (3*(np.sqrt(varcw2)))
lcw4 = meancw2 - (3*(np.sqrt(varcw2)))

#Applying the function for split 1
newcw1 = between(cw1, lcw2, lcw1)
newcw1 = np.array(newcw1)

#Applying the function for split 2
newcw2 = between(cw2, lcw4, lcw3)
newcw2 = np.array(newcw2)

# %%
#Filtering out values in the range of mean plus minus 3 sigma from the two splits for hot water mass flow rates

#Split 1
lhw1 = meanhw1 + (3*(np.sqrt(varhw1)))
lhw2 = meanhw1 - (3*(np.sqrt(varhw1)))

#Split 2
lhw3 = meanhw2 + (3*(np.sqrt(varhw2)))
lhw4 = meanhw2 - (3*(np.sqrt(varhw2)))

#Applying the function for split 1
newhw1 = between(hw1, lhw2, lhw1)
newhw1 = np.array(newhw1)

#Applying the function for split 2
newhw2 = between(hw2, lhw4, lhw3)
newhw2 = np.array(newhw2)

# %%
#Filtering out values in the range of mean plus minus 3 sigma from the two splits for total mass flow rates

#Split 1
ltot1 = meantot1 + (3*(np.sqrt(vartot1)))
ltot2 = meantot1 - (3*(np.sqrt(vartot1)))

#Split 2
ltot3 = meantot2 + (3*(np.sqrt(vartot2)))
ltot4 = meantot2 - (3*(np.sqrt(vartot2)))

#Applying the function for split 1
newtot1 = between(tot1, ltot2, ltot1)
newtot1 = np.array(newtot1)

#Applying the function for split 2
newtot2 = between(tot2, ltot4, ltot3)
newtot2 = np.array(newtot2)

# %% [markdown]
# Kindly note- The graphs for both splits have been plotted in a single graph, and as the split have omitted few points, hence there is a visible gap between the plots of two splits.

# %%
#Plotting split 1 & 2 of cold water mass flow rate
plt.figure(figsize=(20,10)) 
plt.plot(t[0:1500], newcw1, label = 'Cold water mass flow rate Split 1')                  #Taking the same time split as split 1 for cold water mass flow rate
plt.plot(t[1990:], newcw2, label = 'Cold water mass flow rate Split 2')                   #Taking the same time split as split 2 for cold water mass flow rate                                                 
plt.xlabel('Time (Sec.)', fontsize=12)
plt.ylabel('Mass flow rate of cold water (Split 1 & Split 2) (kg/h)',fontsize=12)
plt.title('Cold water mass flow rates (Split 1 & Split 2) V/s Time plot',fontsize=18)
plt.legend()

# %%
#Plotting split 1 & 2 of hot water mass flow rate
plt.figure(figsize=(20,10)) 
plt.plot(t[0:1500], newhw1, label = 'Hot water mass flow rate Split 1')                     #Taking the same time split as split 1 for hot water mass flow rate                               
plt.plot(t[1990:], newhw2, label = 'Hot water mass flow rate Split 2')                      #Taking the same time split as split 2 for hot water mass flow rate                
plt.xlabel('Time (Sec.)', fontsize=12)
plt.ylabel('Mass flow rates of hot water (split 1 & split 2) (kg/h)',fontsize=12)
plt.title('Hot water mass flow rates V/s Time plot',fontsize=18)
plt.legend()

# %%
#Plotting split 1 & 2 of total mass flow rate
plt.figure(figsize=(20,10)) 
plt.plot(t[0:1500], newtot1, label = 'Total mass flow rate Split 1')                          #Taking the same time split as split 1 for total mass flow rate             
plt.plot(t[1990:], newtot2, label = 'Total mass flow rate Split 2')                           #Taking the same time split as split 2 for total mass flow rate              
plt.xlabel('Time (Sec.)', fontsize=12)
plt.ylabel('Total mass flow rates (split 1 & split 2) (kg/h)',fontsize=12)
plt.title('Total mass flow rates V/s Time plot',fontsize=18)
plt.legend()

# %% [markdown]
# Part (D)

# %% [markdown]
# Mass balance closure error (as given in the document)
#
# Em = mt- mhw- mcw

# %%
#Calculating mass balance closure errors 

#For split 1
Em_split1 = tot1-hw1-cw1

#For split 2
Em_split2 = tot2-hw2-cw2

# %%
#Mean and variances of the mass balance closure errors

#For split 1
meanem1 = st.mean(Em_split1)
varem1 = st.variance(Em_split1)
print("The mean of the mass balance closure error for split 1 is:", meanem1)
print("The variance of the mass closure balance error fo split 1 is:", varem1)

#For split 2
meanem2 = st.mean(Em_split2)
varem2 = st.variance(Em_split2)
print("The mean of the mass balance closure error for split 2 is:", meanem2)
print("The variance of the mass closure balance error fo split 2 is:", varem2)
# Out:
# The mean of the mass balance closure error for split 1 is: -16.64471827852119
# The variance of the mass closure balance error fo split 1 is: 199.07582137931252
# The mean of the mass balance closure error for split 2 is: 0.7989105452638394
# The variance of the mass closure balance error fo split 2 is: 129.41425647349996

# %%
#Plotting histogram for mass balance closure error for split 1
plt.figure(figsize=(15,10)) 
sns.distplot(Em_split1, hist=True, kde=False, 
             bins=int(180/5), color = 'blue',
             hist_kws={'edgecolor':'black'})
# Add labels
plt.title('Histogram showing the mass balance closure error for split 1',fontsize=18)
plt.xlabel('Error Value',fontsize=12)
plt.ylabel('Frequency',fontsize=12)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0, 0.5, 'Frequency')

# %%
#Plotting histogram for mass balance closure error for split 2
plt.figure(figsize=(15,10)) 
sns.distplot(Em_split2, hist=True, kde=False, 
             bins=int(180/5), color = 'blue',
             hist_kws={'edgecolor':'black'})
# Add labels
plt.title('Histogram showing the mass balance closure error for split 2')
plt.xlabel('Error Value')
plt.ylabel('Frequency')
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# ####Which of these two data sets appears to give reasonably ‘close-to-zero’ closure errors? Do the flow sensors appear to give consistent results?
#
# - The second split of the data appears to give a 'close-to-zero' closure error. All of the flow sensors seem to give consistent results except the cold water flow sensor, which seems to be inconsistent and exhibits some unnatural behaviour.

# %% [markdown]
# Part (E)

# %%
#Plotting temperatures T4 and T5
plt.figure(figsize=(30,20)) 
plt.plot (data['Time (Sec.)'], data['T4 (Deg C)'], label= 'T4 temperature')
plt.plot (data['Time (Sec.)'], data['T5 (Deg C)'], label= 'T5 temperature')
plt.xlabel('Time (Sec.)', fontsize=18)
plt.ylabel('Temperatures (Deg C)',fontsize=18)
plt.title('Temperature V/s Time plot',fontsize=20)
plt.legend()

# %%
#Assigning variables to temperatures T4 & T5
datat4 = data['T4 (Deg C)']
datat5 = data['T5 (Deg C)']

#Splitting the data for the segments where they seem to be visually stationary
t4split = datat4.iloc[1800:2300]                    #Segment has been done according to the visual judgement of the stationary segment
t5split = datat5.iloc[2500:2800]

# %%
#Plotting histogram for showing the distribution of the steady state split for temp T4
plt.figure(figsize=(15,10)) 
sns.distplot(t4split, hist=True, kde=False, 
             bins=int(180/6), color = 'blue',
             hist_kws={'edgecolor':'black'})
# Add labels
plt.title('Histogram showing the distribution of the steady state for temp T4 ',fontsize=18)
plt.xlabel('Temp (T4) Deg C', fontsize=12)
plt.ylabel('Frequency',fontsize=12)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0, 0.5, 'Frequency')

# %%
#Plotting histogram for showing the distribution of the steady state split for temp T5
plt.figure(figsize=(15,10)) 
sns.distplot(t5split, hist=True, kde=False, 
             bins=int(180/18), color = 'blue',
             hist_kws={'edgecolor':'black'})
# Add labels
plt.title('Histogram showing the distribution of the steady state for temp T5 ',fontsize=18)
plt.xlabel('Temp (T5) Deg C', fontsize=12)
plt.ylabel('Frequency',fontsize=12)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0, 0.5, 'Frequency')

# %%
#Computing the mean and variances of the temperature measurements

#For temperature T4
meant4_ = st.mean(t4split)
vart4 = st.variance(t4split)

#Printing the mean and variance for T4
print("The mean of the T4 temperature measurements is:",meant4_)
print("The variance of the T4 temperature measurements is:",vart4)

#For temperature T4
meant5_ = st.mean(t5split)
vart5 = st.variance(t5split)

#Printing the mean and variance for T4
print("The mean of the T5 temperature measurements is:",meant5_)
print("The variance of the T5 temperature measurements is:",vart5)
# Out:
# The mean of the T4 temperature measurements is: 43.18926
# The variance of the T4 temperature measurements is: 0.7787812148296597
# The mean of the T5 temperature measurements is: 35.06016666666667
# The variance of the T5 temperature measurements is: 0.1926926142697895

# %% [markdown]
# ####Comment as to why the variance of one of the temperature measurements is different than the other.
#
# The variance for T4 measurements is different than that of T5 measurements as it is evident that the T4 temperature sensor is placed just after the mixing of hot and cold water streams, when the temperature is still fluctuating and hasn't reached a comparitively steady state whereas by the time a reading is recorded in T5 temperature sensor, it has attained a relatively steady state in terms of temperature and the changes are slowly minimized.

# %% [markdown]
# Part (H)

# %% [markdown]
# Closure error = T4-T5 (assuming heat capacities are insensitive to the temperature variations)

# %%
#Calculating energy balance closure error according to the equation
cetemp = datat4-datat5

#Calculating the mean and variance of the closure error
meancetemp = st.mean(cetemp)
varcetemp = st.variance(cetemp)

#Printing the mean and variance of energy balance closure error
print("The mean of energy balance closure error is:",meancetemp)
print("The variance of energy balance closure error is:",varcetemp)
# Out:
# The mean of energy balance closure error is: 7.630588628762541
# The variance of energy balance closure error is: 1.069477873540777

# %% [markdown]
# Part (I)

# %%
#Plotting histogram for showing the energy balance closure error
plt.figure(figsize=(15,10)) 
sns.distplot(cetemp, hist=True, kde=False, 
             bins=int(180/5), color = 'blue',
             hist_kws={'edgecolor':'black'})
# Add labels
plt.title('Histogram showing the energy balance closure error ',fontsize=18)
plt.xlabel('Temp Deg C', fontsize=12)
plt.ylabel('Frequency',fontsize=12)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# ####Do you think there is a gross error with either one of T4 or T5 sensors?
#
# Yes, there seems to be a gross error in either T4 or T5

# %% [markdown]
# Part (J)

# %% [markdown]
# Energy balance equations:
#
# ce = mcw*Cp1*T1+mhw*Cp2*T2-mt*Cp3*T4
#
# ce = mcw*Cp1*T1+mhw*Cp2*T2-mt*Cp3*T5
#
# (Assuming heat capacities are insensitive to the temperature variations)

# %%
#Assigning temperature to the variables
t1 = data['T1 (Deg C)'][1990:]
t2 = data['T2 (Deg C)'][1990:]
t4 = data['T4 (Deg C)'][1990:]
t5 = data['T5 (Deg C)'][1990:]

# %%
#As given in the assignment question file
cet4 = ((cw2*t1)+(hw2*t2)-(tot2*t4))        #Using second split of the mass flow rate data  as well as temperature from the analysis done above and as per the instruction in the question document in part (f)
cet5 = ((cw2*t1)+(hw2*t2)-(tot2*t5))

# %%
#Plotting histogram for closure error for T4
plt.figure(figsize=(15,10)) 
sns.distplot(cet4, hist=True, kde=False, 
             bins=int(180/5), color = 'blue',
             hist_kws={'edgecolor':'black'})
# Add labels
plt.title('Histogram for closure error for T4',fontsize=18)
plt.xlabel('Temp Deg C', fontsize=12)
plt.ylabel('Frequency',fontsize=12)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0, 0.5, 'Frequency')

# %%
#Plotting histogram for closure error for T5
plt.figure(figsize=(15,10)) 
sns.distplot(cet5, hist=True, kde=False, 
             bins=int(180/5), color = 'blue',
             hist_kws={'edgecolor':'black'})
# Add labels
plt.title('Histogram for closure error for T4',fontsize=18)
plt.xlabel('Temp Deg C', fontsize=12)
plt.ylabel('Frequency',fontsize=12)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0, 0.5, 'Frequency')

# %%
#Closure error for T4
meancet4 = st.mean(cet4)
varcet4 = st.variance(cet4)
print("The mean of the closure error for T4 temperature measurements is:",meancet4)
print("The variance of the closure error for T4 temperature measurements is:",varcet4)

#Closure error for T5
meancet5 = st.mean(cet5)
varcet5 = st.variance(cet5)
print("The mean of the closure error for T5 temperature measurements is:",meancet5)
print("The variance of the closure error for T5 temperature measurements is:",varcet5)
# Out:
# The mean of the closure error for T4 temperature measurements is: -4740.536356667558
# The variance of the closure error for T4 temperature measurements is: 531759.0169270189
# The mean of the closure error for T5 temperature measurements is: 75.43306523167385
# The variance of the closure error for T5 temperature measurements is: 251174.97642157396

# %% [markdown]
# ####Which of the above energy balances give the most reasonable closure errors? Based on this, which of T4 or T5 sensor is likely to contain gross error?
#
# Based on the analysis done above, *T5* gives a reasonably 'close-to-zero' closure error. *T4*, in this case, can be said to have a gross error.
